# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob

# %%
df = pd.read_csv('../../data/raw_analyst_ratings.csv')

# %%
publisher_counts = df['publisher'].value_counts()

# Display top 10 most active publishers
print(publisher_counts.head(10))
# Out:
# publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
# Eddie Staley          57254
# Hal Lindon            49047
# ETF Professor         28489
# Juan Lopez            28438
# Benzinga Staff        28114
# Name: count, dtype: int64

# %%
# Visualize publisher activity
plt.figure(figsize=(10,5))
sns.barplot(x=publisher_counts.head(10).index, y=publisher_counts.head(10).values, palette="Blues_d")
plt.xlabel("Publisher")
plt.ylabel("Number of Articles")
plt.title("Top 10 Most Active Publishers")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Abdilfatah\AppData\Local\Temp\ipykernel_2416\4250424417.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=publisher_counts.head(10).index, y=publisher_counts.head(10).values, palette="Blues_d")

# %%
# Example category keyword sets
categories = {
    'Business': ['stock', 'market', 'trade', 'price', 'finance', 'bank'],
    'Politics': ['government', 'election', 'policy', 'law', 'vote', 'senate'],
    'Technology': ['AI', 'tech', 'software', 'hardware', 'innovation'],
    'Health': ['medicine', 'doctor', 'health', 'disease', 'virus']
}

# %%
# Apply classification to headlines or article text
df['News Category'] = df['headline'].apply(categorize_news)

# Count categories
category_counts = df['News Category'].value_counts()

# %%
# Visualize category distribution
plt.figure(figsize=(10,5))
category_counts.plot(kind='bar', color='skyblue')
plt.xlabel("News Category")
plt.ylabel("Number of Articles")
plt.title("Distribution of News Categories")
plt.xticks(rotation=45)
plt.show()

# %%
# Extract domains from email addresses
df['Domain'] = df['publisher'].str.extract(r'@([a-zA-Z0-9.-]+)')

# Count occurrences
domain_counts = df['Domain'].value_counts()

# Display top domains
print(domain_counts.head(10))

# Visualize top domains
plt.figure(figsize=(10,5))
domain_counts.head(10).plot(kind='bar', color='skyblue')
plt.xlabel("Email Domain")
plt.ylabel("Number of Articles")
plt.title("Top 10 Most Active Publishing Domains")
plt.xticks(rotation=45)
plt.show()
# Out:
# Domain
# benzinga.com              7937
# gmail.com                  139
# andyswan.com                 5
# investdiva.com               2
# tothetick.com                2
# eosdetroit.io                1
# forextraininggroup.com       1
# stockmetrix.net              1
# Name: count, dtype: int64
